# %% [markdown]
# <a href="https://colab.research.google.com/github/jovanidhh/SMAE-NN/blob/main/CODE_NEURAL_NETWORK_SMAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
PROYECTO: SMAE neural network 
Created on Tue 10 18:12:15 2022

"""

#@title __Init__ { vertical-output: true, form-width: "50%", display-mode: "form" }
import matplotlib.pyplot as plt
from google.colab import files
from os import remove
import pandas as pd
import numpy as np
import numpy



class neural_layer():
  def __init__(self, n_conn, n_neur, act_f):
    self.act_f = act_f
    self.b = np.random.rand(1, n_neur)
    self.w = np.random.rand(n_conn, n_neur)

sigm = (lambda x: 1/(1+np.e**(-x)),
        lambda a: a * (1-a))
tanh = (lambda x: np.tanh(x),
        lambda x: 1-x**2
        )
relu = (lambda x: np.maximum(0,x),
        lambda x: 1
        )
l2_cost = (lambda Yp, Yr: np.mean((Yp-Yr)**2), 
        lambda Yp, Yr: (Yp - Yr))

def create_nn(topology, act_f):
  nn = []
  for l, layer in enumerate(topology[:-1]):
    nn.append(neural_layer(topology[l], topology[l+1], act_f))
  return nn

def train(neural_net, X, l2_cost, lr = 0.5, train = True):  
    out = [(None, X)]
    for l, layer in enumerate(neural_net):
        z = out[-1][1] @ neural_net[l].w + neural_net[l].b
        a = neural_net[0].act_f[0](z)
        out.append((z,a))
    return out[-1][1]

def corrector(STR):
  if STR[-1] ==' ':
    return STR[:-1]
  return STR

def Y_target(f):
  if Xdb.shape[1] > 13: 
    WN= list(Wn)
    Yn = Xdb[:,13].astype('str')
    YY = []
    for yi,y in enumerate(Yn):
      YY.append([f[0]]*19)
      YY[yi][WN.index(corrector(y))]=f[1]
  return YY

def XS(X):
  Xs= np.empty((len(X),4))
  for i in range(len(X)):
    #EXCESO DE CALORÍAS
    Xs[i,0]= round((X[i,0]-275)/275+1,2)
    #EXCESO DE AZÚCARES
    Xs[i,1]= round((X[i,6]-X[i,0]*.1/4)/(X[i,0]*.1/4)+1,2)
    #EXCESO DE GRASAS SATURADAS
    Xs[i,2]= round((X[i,2]-X[i,0]*.1/9)/(X[i,0]*.1/9)+1,2)
    #EXCESO DE SODIO
    Xs[i,3]= round((X[i,8]-300)/300+1,2)
  return Xs

def N_efectiva(V):
  len = V.shape
  ds = np.empty(len[0])
  for j in range(len[0]):
    ds[j] = np.linalg.norm([V[j,0],V[j,1],V[j,2],V[j,5],V[j,6]])
  return ds

def N(V):
  len = V.shape
  ds = np.empty(len[0])
  for j in range(len[0]):
    ds[j] = np.linalg.norm(V[j,:])
    if ds[j] != 0:  V[j,:] /= ds[j]
  return ds
  
def NNCP(Xdb):
  Xn = np.array(Xdb[:,0:2])
  Xu   = np.array(Xdb[:,2:4]).astype(float)
  X   = np.array(Xdb[:,4:13]).astype(float)
  X[:,5]  = X[:,5]-X[:,6]-X[:,7]   # Carbs -fibra - azucar
  X[:,2]  = X[:,2]-X[:,3]          # Grasas totales - Ag sat
  len_x = len(X)
  len_a0 = len(X[0,:])
  len_al = len(Wn)
  Xs = XS(X)
  dsxefectiva = N_efectiva(X)
  #funciones normalizadora
  for i, Xcol in enumerate(X.T):
    X[:,i] /= Xmean[i]
  #Obtención de normas
  dsx = N(X)
  for i in range(len_x): 
    if dsx[i] != 0:
      dsx[i]= dsx[i]*.0001
  X= np.append(X,np.array(dsx[:,np.newaxis]),axis= 1)
  return X,train(neural_n, X, l2_cost,train = False),Xs,Xn,Xu,dsxefectiva

_X_ = np.linspace(0.995 ,1,100)

PROBABILIDAD = [lambda x :2/(1+np.e**(np.power(-x-.0003,8001)))-1,
                lambda x : numpy.arccos(x-0.0000000001)]

_Y_=PROBABILIDAD[0](_X_)
_Y1_=PROBABILIDAD[1](_X_)

"""
#si posteriormente se quiere actualizar el aprendizaje de la red
dfnn = []
topology = []
Wb = []
uploaded = files.upload()
i=0
for fn in uploaded.keys():
  name = fn
  dfnn.append(pd.read_csv(name,encoding ='iso-8859-1',header=0))#dataframe
  Wb.append((np.array(dfnn[i].values)[:-1,1:],np.array(dfnn[i].values)[-1,1:] ))
  if i == 0: topology.insert(0,(Wb[i][0].shape[0]))
  topology.append(Wb[i][0].shape[1])
  remove(name)
  i+=1

j=0
for i in range(0,len(neural_n)):
  neural_n[j].w = Wb[i][0]
  neural_n[j].b = Wb[i][1]
  j+=1
"""
topology = [10,50,19]
Wn = np.array([
       'Aceites y grasas con proteína', #1
       'Aceites y grasas sin proteína',#2
       'Libre', #3
       'AOAA',#4
       'AOAB', #5
       'AOAM',#6
       'AOAMB', #7
       'Azúcares con grasa',#8
       'Azúcares sin grasa', #9
       'Etanol',#10
       'Cereales y tubérculos con grasa',#11
       'Cereales y tubérculos sin grasa', #12
       'Frutas', #13
       'Leche con azúcar',#14
       'Leche descremada', #15
       'Leche entera', #16
       'Leche semidescremada',#17
       'Leguminosas', #18
       'Verduras'#19
       ], dtype=object)
dsw = np.array([ 70.27503905,  45.27987837, 170.12789307, 100.56341283,
        55.52476925,  75.4917214 ,  40.62019202,  85.55410948,
        40.89990349, 197.62859105, 115.64131552,  71.27787825,
        61.28099236, 202.45740293,  96.19771307, 150.96025967,
      111.09005356, 121.92210628,  25.3968502 ])
Xmean = [250.50367049,   9.26145116,   7.45498471,   3.40892735,  34.5278554,
  16.95607925,  10.23195342,   3.13060827, 362.05574303]
HEAD = {
    0: 'Sim 1', 2: 'Grupo', 1: 'Equiv./U', 
    3: 'Sim 2', 5: 'Grupo', 4: 'Equiv./U',
    6: 'Sim 3', 8: 'Grupo', 7: 'Equiv./U',
    
    9:'Alimento', 10: 'U', 11: "Peso/U" ,  12: 'P.C',
    13: 'Kcal', 14:'Prót.', 15: 'Líp.', 16: 'AG Sat.', 
    17: 'Coles.', 18: 'Carbs', 19: 'Azúc.', 20: 'Fib.', 21: 'Sod',
    22: 'Exce. Calorías',
    23: 'Exce. Azúcares',
    24: 'Exce. Grasas Sat.',
    25: 'Exce. de Sodio'
    }

neural_n = create_nn(topology, tanh)


neural_n[0].b = np.array([-0.20963885,  0.07514731,  0.18091527, -0.09101178, -0.20330104,
        0.08930003,  0.00355253,  0.05284653,  0.05329237,  0.1117731 ,
      -0.24392833, -0.0922279 , -0.18523491, -0.18473335,  0.18510091,
        -1.09507193,  0.84379189, -1.86512481, -0.06258932, -0.47417826,
        0.30964137, -1.89151324,  0.77509637, -1.27081796, -0.52275715,
        -0.29638848, -0.25728831, -2.63383164,  0.43953004],
      [ 0.66208441, -1.14363515,  2.37765084,  0.37607781, -1.85186247,
        1.11319298,  2.98634843,  0.25171855,  4.80624991,  1.32975958,
        -2.13578069, -4.93020127,  1.06651791,  0.72186786,  0.32998957,
        -0.47744256, -0.16115007,  2.74752105,  3.92985802],
      [-2.79935811,  3.23553282, -1.50891512,  1.53697041, -4.18683539,
        2.59496899, -0.09464364,  0.3159794 , -0.52360601,  0.57129795,
        2.70111185,  0.73281374,  1.51693076,  0.9444835 ,  0.01730439,
        0.96773438, -1.15963068,  0.68407335, -3.93607376],
      [ 2.95798462, -2.31094512,  0.3116013 ,  0.12948159, -0.99974366,
        -0.89379052,  0.7071507 , -1.62990282, -1.19908229, -0.76916443,
        -2.19947692, -0.105495  ,  0.01208926, -3.07895192, -2.99781006,
        -0.80451273, -0.41526203,  4.26432732, -5.88784891]])

print("Uploaded Neural Network SMAE with topology",topology)


"""
"""
# weights = []
# for i, layer  in enumerate(neural_n):
#   weights.append(np.append(layer.w.T,layer.b.T,axis= 1).T)
#   df = pd.DataFrame(weights[i])
#   filepath = Path(r"C:\Users\johan\Desktop\LAYER_2__{}.csv".format(i))  
#   filepath.parent.mkdir(parents=True, exist_ok=True)  
#   df.to_csv("NL_{}.csv".format(i)) 


FLAGS = [0,0]
# Out:
# Uploaded Neural Network SMAE with topology [10, 50, 19]

# %%
#@title ####__Datos->Origen->Alimento__ { run: "auto", vertical-output: true, form-width: "50%", display-mode: "form" }

Inf_nutrimental_por ="100g" #@param ["100g", "Unidad"]
Unidades_de_medida =    "Piezas" #@param ["gr", "Cucharadas", "Tazas", "Piezas", "Seg. de dispersión"]
Peso_de_cada_unidad_en_gramos =     230#@param     {type:"number"}
Porción_comestible =     1#@param     {type:"number"}
Energía =     495#@param     {type:"number"}
Proteínas =   5.6#@param    {type:"number"}
Lípidos_Totales =      22.4#@param       {type:"number"}
AG_Saturados =  7.8#@param       {type:"number"}
Colesterol =  0#@param       {type:"number"}
Carbohidratos =  67.8#@param {type:"number"}
Azúcar =     27.5#@param {type:"number"}
Fibra =  2.6#@param {type:"number"}
Sodio_mg =  250#@param {type:"number"}

FLAGS[0] = 1

print("Datos Guardados")
Xdb =np.array( [["Alimento",
                Unidades_de_medida, 
                Peso_de_cada_unidad_en_gramos,
                Porción_comestible,
                Energía,
                Proteínas,
                
                Lípidos_Totales,
                AG_Saturados,
                Colesterol,
                
                Carbohidratos,
                Azúcar,
                Fibra,
                Sodio_mg
                 ]])

if Inf_nutrimental_por =="Unidad":
  for i in range(9):
    Xdb[0,i+4]=Xdb[0,i+4].astype(float)/Peso_de_cada_unidad_en_gramos*100


cxXn  = np.array(Xdb[:,0:2])
cxXu   = np.array(Xdb[:,2:4]).astype(float)
cxX   = np.array(Xdb[:,4:13]).astype(float)
cxX[:,5]  = cxX[:,5]-cxX[:,6]-cxX[:,7]
# Out:
# Datos Guardados

# %%
#@title #####__Datos->Origen->BASE DE DATOS__ { run: "auto", vertical-output: true, form-width: "50%", display-mode: "form" }

uploaded = files.upload()
for fn in uploaded.keys():
  namecsv = fn
dfSMAE=pd.read_csv(namecsv,encoding ='iso-8859-1', na_values=[' ','',str,'ND','#¿NOMBRE?'], header=0) #dataframe
dfSMAE = dfSMAE.fillna(0)
remove(namecsv)
Xdb = np.array(dfSMAE.values)

def formaterrors(Xdb):
  Errores =[]
  for i in range(11):
    for j, v in enumerate(Xdb[:,2+i]):
      if type(v) == str:
        string = list(v)
        Correct_str = ''
        flag =0
        banderaerror = False
        for index,character in enumerate(string):
          if character in set(np.array(range(10)).astype(str)):
            Correct_str += character
          elif character == '.' and flag ==0:
            Correct_str += character
            flag =1
          else:
            banderaerror = True
        if banderaerror:
          Xdb[j,2+i] =float(Correct_str)
          Errores.append("in column {}, row {}: {} \"{}\"\t{} {} {}".format(i+2,j,type(v),v, "was converted to ",Xdb[j,2+i],type(Xdb[j,2+i])))

  print("\n Se corriegieron {} errores de formato\n".format(len(Errores)))
  Xdb[:,2:12] = Xdb[:,2:12].astype(float)
  for i, v in  enumerate(Errores):
    print(v)
  
formaterrors(Xdb)


cXn  = np.array(Xdb[:,0:2])
cXu   = np.array(Xdb[:,2:4]).astype(float)
cX   = np.array(Xdb[:,4:13]).astype(float)
cX[:,5]  = cX[:,5]-cX[:,6]-cX[:,7] 
clen_x = len(cX)

FLAGS[1] = 1
FLAGS[0] = 0
# Out:
#      <input type="file" id="files-c77549f1-44d9-4eb3-9017-bb44b70a1f19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c77549f1-44d9-4eb3-9017-bb44b70a1f19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DB SMAE V11_2.csv to DB SMAE V11_2.csv
#
#  Se corriegieron 1 errores de formato
#
# in column 12, row 2706: <class 'str'> "428. 5"	was converted to  428.5 <class 'float'>

# %%
dfSMAE
# Out:
#                                                Alimento Unidad individual  \
# 0                  Aderezo blue cheese bajo en calorías         cucharada
# 1                                       Aderezo de miel         cucharada
# 2            Aderezo de miel y mostaza bajo en calorías         cucharada
# 3                      Aderezo francés bajo en calorías         cucharada
# 4                    Aderezo mil islas bajo en calorías         cucharada
# ...                                                 ...               ...
# 2872  Barra Kellogg's® Special K® Nut Bar Sabor a ch...             barra
# 2873      Barra Kellogg's® Special K® Nut Bar Arándanos             barra
# 2874  Barra Kellogg's® Special K® Sabor vainilla y f...             barra
# 2875   Barra Kellogg's® Special K® Chocolate semiamargo             barra
# 2876           Barra Kellogg's® Special K® Cosecha roja             barra
#
#       Peso unitario individual  Porción comestible  Energía  Proteína  \
# ...

# %%
#@title #####__RESULTADO DEL ANÁLISIS__  { run: "auto", form-width: "50%", display-mode: "form" }
bias = .15

X_inputNN, OUT,Xs,Xn,Xu,dsxefectiva= NNCP(Xdb)
Y = OUT.T
k=3
for i, serie in enumerate(X_inputNN[:,:-1].T):
  dfSMAE[dfSMAE.columns.values.tolist()[4:13][i]] = serie

y = np.zeros((len(Xdb),3*k)).astype(str)

Errortype =np.empty(len(Xdb))
probabilidad =0
for i in range(len(Xdb)):
  lst = []
  maxsim = []
  for j in range(k):
    p = np.argmax(Y[:,i])
    maxsim.append(p)
    lst.extend(("{}%".format(round(Y[p,i]*50+50,1)),"{}".format(round(dsw[p]/(dsxefectiva[i]*Xu[i,0]*Xu[i,1])*100,1),Xn[i,1]),Wn[p]))#"Xn[i,1]"
    if Y[p,i] > bias: probabilidad +=1
    Y[p,i] = -2
  y[i,:] = lst
counter =[0] * 19



arr = np.append(y,Xdb,axis= 1)
arr = np.append(arr,Xs,axis= 1)
dff = pd.DataFrame(arr)
dff.rename(columns=HEAD,inplace=True)

if FLAGS[0] ==1:
  print("UNIDADES EQUIVALENTES DE LOS GRUPOS ALIMENTICIOS MÁS PROBABLES")
 
  print("-"*11,"+","-"*9,"+","-"*36)
  for h, v in enumerate(arr[0,:3]):
    print("| {:<10}".format(v),sep='\t',end='')
  print("\n",end='')
  for h, v in enumerate(arr[0,3:6]):
    print("| {:<10}".format(v),sep='\t',end='')
  print("\n",end='')
  for h, v in enumerate(arr[0,6:9]):
    print("| {:<10}".format(v),sep='\t',end='')
  print('\n',"-"*10,"+","-"*9,"+","-"*36)
  print("\n\n",end='')

  print("CANTIDADES EN EXCESO")
  print("-"*6,"+","-"*53)
  print("{:<6} | Exceso de calorías \n{:<6} | Exceso de Azúcares\n{:<6} | Exceso de Grasas Trans\n{:<6} | Exceso de Sodio".format(Xs[0,0],Xs[0,1],Xs[0,2],Xs[0,3]))
  print("-"*6,"+","-"*53)
  print("\n\n",end='')
  if FLAGS[1] ==1:
    cdsx = N_efectiva(cxX)
    cdsxdb = N_efectiva(cX)
    _cX = np.copy(cX)
    _cxX = np.copy(cxX)
    N(_cX)
    N(_cxX)
    Y=_cX@_cxX.T
    print("CANTIDAD EQUIVALENTE NECESARIA DE ALIMENTOS SIMILARES")
    print("\n",end='')
    XNAMES = ["E","P","L","S","C","H","A","F","N"]
    for i, v in enumerate(XNAMES):
      print("  {}   ".format(v),end='|')
    print("\n",end='')
    print("-"*5,"+","-"*4,"+","-"*4,"+","-"*4,"+","-"*4,"+","-"*4,"+","-"*4,"+","-"*4,"+","-"*4)
    for h, v in enumerate(cxX[0,:]):
      print("{:<6}".format(round(v,1)),sep='\t',end='|')
    print("\n",end='')
    print("-"*5,"+","-"*4,"+","-"*4,"+","-"*4,"+","-"*4,"+","-"*4,"+","-"*4,"+","-"*4,"+","-"*4)
    for i in range(10):
      lst = []
      maxsim = []
      p = np.argmax(Y[:,0])
      maxsim.append(p)
      #cdsx[0]*(2-2*Y[p,0])**.5,5)
      for h, v in enumerate(cX[p,:]):
        print("{:<6}".format(round(v,1)),sep='\t',end='|')
      print("\tEquivalente a\t{} {}s de \t\t{}".format(round(cdsx[0]*cxXu[0,1]/(cdsxdb[p]*cXu[p,1]),1), cXn[p,1] ,cXn[p,0]), )
      Y[p,0] = -2
else: 
  #print("El 87% de los datos correctos entre los primeros tres lugares tienen un puntaje arriba de 15 %  ")
  dff.to_csv("Sorted{}".format(namecsv), encoding= 'iso-8859-1')
dff

dfSMAE.to_csv("dfSMAE{}".format(".csv"), encoding= 'iso-8859-1')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: RuntimeWarning: divide by zero encountered in double_scalars

# %% [markdown]
# GRÁFICAS

# %%
import plotly.graph_objects as go

import pandas as pd
N=10
c = ['hsla('+str(h)+',50%'+',50%,0)' for h in np.linspace(0, 360, N)]
cwa = ['hsla('+str(h)+',80%'+',50%,1)' for h in np.linspace(0, 360, N)]

CMAP = "gist_ncar"
cwa_cm = ['rgba'+str((plt.cm.get_cmap(CMAP,N)(i)[0]*255,plt.cm.get_cmap(CMAP,10)(i)[1]*255,plt.cm.get_cmap(CMAP,10)(i)[2]*255,plt.cm.get_cmap(CMAP,10)(i)[3])) for i in range(N)]
Subgrupos = list(Wn)
fig = go.Figure()
i = 0
for nutrcomp in dfSMAE.columns.values.tolist()[4:13]:
  for Subgrupo in Subgrupos:
      fig.add_trace(go.Violin(x=pd.Series([Subgrupo]*len(dfSMAE[nutrcomp][dfSMAE['Subgrupo'] == Subgrupo]), copy=False),
                              y=dfSMAE[nutrcomp][dfSMAE['Subgrupo'] == Subgrupo],
                              #name=Subgrupo,
                              legendgroup=nutrcomp,
                              name=nutrcomp,
                              legendgrouptitle_text=nutrcomp,
                              box_visible=False,
                              meanline_visible=False,
                              bandwidth=0,width=0,
                              opacity =1,
                              line_color=c[i],
                              marker_opacity =.35,
                              marker_size = 3, 
                              marker_color =cwa_cm[i],
                              line_width =0,
                              fillcolor = c[i]
                              ))
  i+=1
          
fig.update_traces(box_visible=False, meanline_visible=False, points="all", pointpos = 0, jitter = 0)
fig.update_layout(violinmode='group',
                  template="plotly_white",
                  violingap=0.2,
                  xaxis_showgrid = False,
                  yaxis_showgrid = False,
                  yaxis_zeroline = True,
                  legend_traceorder = "grouped",
                  paper_bgcolor = "rgb(237,237,237)",
                  legend_tracegroupgap=5,
                  width=1500,
                  height=800,
                  font = dict(family="Serif", 
                              color='black',
                              size=18),
                  margin=dict(
                          l=50,
                          r=50,
                          b=100,
                          t=40,
                          pad=4
                      ),
                  yaxis_range=[0,1]

                  )

# fig.savefig("eps_Figure_example.png", format='png',dpi=800, bbox_inches='tight')
fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_image("images/fig1.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-81433d09fdb2> in <module>()
# ----> 1 fig.write_image("images/fig1.png")
#
# /usr/local/lib/python3.7/dist-packages/plotly/basedatatypes.py in write_image(self, *args, **kwargs)
#    3827         import plotly.io as pio
#    3828
# -> 3829         return pio.write_image(self, *args, **kwargs)
#    3830
#    3831     # Static helpers
#
# /usr/local/lib/python3.7/dist-packages/plotly/io/_kaleido.py in write_image(fig, file, format, scale, width, height, validate, engine)
#     273         height=height,
#     274         validate=validate,
# --> 275         engine=engine,
#     276     )
#     277
#
# /usr/local/lib/python3.7/dist-packages/plotly/io/_kaleido.py in to_image(fig, format, width, height, scale, validate, engine)
#     137 which can be installed using pip:
#     138     $ pip install -U kaleido
# ...

# %%
pip install -U kaleido
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 79.9 MB 116 kB/s
# ...
